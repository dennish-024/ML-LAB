# %%
#NaiveBayes Test Classification
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report, accuracy_score
import numpy as np

# %%
texts = [
    "The match was exciting and the team played well",  # Sports
    "The government passed a new law today",            # Politics
    "The new smartphone has amazing features",          # Technology
    "The actor won an award for best performance",      # Entertainment
    "The player scored a hat-trick in the game",        # Sports
    "The parliament discussed the budget proposal",     # Politics
    "The software update improves battery life",        # Technology
    "The movie received great reviews from critics"     # Entertainment
]

label= ["Sports","Politics","Technology","Entertainment","Sports","Politics","Technology","Entertainment"]

# %%
vectorizer=CountVectorizer()
X= vectorizer.fit_transform(texts)
X_train,x_test,y_train,y_test=train_test_split(X,label,test_size=0.4,random_state=42,stratify=label)

# %%
model=MultinomialNB()
model.fit(X_train,y_train)
# Out:
# MultinomialNB()

# %%
y_pred=model.predict(x_test)
print("Classification Report:",classification_report(y_test,y_pred))
print("Accuracy Score:",accuracy_score(y_test,y_pred),(100,2),"%")
# Out:
# Classification Report:                precision    recall  f1-score   support
#
# Entertainment       0.00      0.00      0.00         1
#      Politics       0.00      0.00      0.00         1
#        Sports       0.33      1.00      0.50         1
#    Technology       0.00      0.00      0.00         1
#
#      accuracy                           0.25         4
#     macro avg       0.08      0.25      0.12         4
#  weighted avg       0.08      0.25      0.12         4
#
# Accuracy Score: 0.25 (100, 2) %
# d:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %%
new_text=[
    "Kohli is in 2nd place of ODI ranking list",
    "Modi will be the next PM again",
    "Technology changing the world",
    "Samay Raina's standup is source of entertainment"
]

# %%
new_x=vectorizer.transform(new_text)
prediction=model.predict(new_x)
for text,label in zip (new_text,prediction):
    print(f"'{text}'->'{label}'")
# Out:
# 'Kohli is in 2nd place of ODI ranking list'->'Sports'
# 'Modi will be the next PM again'->'Sports'
# 'Technology changing the world'->'Sports'
# 'Samay Raina's standup is source of entertainment'->'Entertainment'

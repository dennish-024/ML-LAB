# %%
import pandas as pd
df= pd.DataFrame({'col1':[1,2,3,4], 'col2': ['abc','def','ghi','xyz'], 'col3': [111,222,333,444]})
df
# Out:
#    col1 col2  col3
# 0     1  abc   111
# 1     2  def   222
# 2     3  ghi   333
# 3     4  xyz   444

# %%
df.head()
# Out:
#    col1 col2  col3
# 0     1  abc   111
# 1     2  def   222
# 2     3  ghi   333
# 3     4  xyz   444

# %%
df.tail()
# Out:
#    col1 col2  col3
# 0     1  abc   111
# 1     2  def   222
# 2     3  ghi   333
# 3     4  xyz   444

# %%
df.shape
# Out:
# (4, 3)

# %%
df.count()
# Out:
# col1    4
# col2    4
# col3    4
# dtype: int64

# %%
df['col2'].count()
# Out:
# 4

# %%
df['col2'].unique()
# Out:
# array(['abc', 'def', 'ghi', 'xyz'], dtype=object)

# %%
df.col2.unique()
# Out:
# array(['abc', 'def', 'ghi', 'xyz'], dtype=object)

# %%
df['col2'].nunique()
# Out:
# 4

# %%
df["col2"].value_counts()
# Out:
# col2
# abc    1
# def    1
# ghi    1
# xyz    1
# Name: count, dtype: int64

# %%
import numpy as np
df1= pd.DataFrame({'col1':[np.nan,2,3,4,5,6], 'col2': ['abc','def',np.nan,'xyz','pqr','def'], 'col3': [111,222,np.nan,444,111,555]})
df1
# Out:
#    col1 col2   col3
# 0   NaN  abc  111.0
# 1   2.0  def  222.0
# 2   3.0  NaN    NaN
# 3   4.0  xyz  444.0
# 4   5.0  pqr  111.0
# 5   6.0  def  555.0

# %%
df1.head()
# Out:
#    col1 col2   col3
# 0   NaN  abc  111.0
# 1   2.0  def  222.0
# 2   3.0  NaN    NaN
# 3   4.0  xyz  444.0
# 4   5.0  pqr  111.0

# %%
df1.tail()
# Out:
#    col1 col2   col3
# 1   2.0  def  222.0
# 2   3.0  NaN    NaN
# 3   4.0  xyz  444.0
# 4   5.0  pqr  111.0
# 5   6.0  def  555.0

# %%
df1['col2'].unique()
# Out:
# array(['abc', 'def', nan, 'xyz', 'pqr'], dtype=object)

# %%
df1['col2'].nunique()
# Out:
# 4

# %%
df1.shape
# Out:
# (6, 3)

# %%
df1['col2'].value_counts()
# Out:
# col2
# def    2
# abc    1
# xyz    1
# pqr    1
# Name: count, dtype: int64

# %%
df1.sort_values('col2')
# Out:
#    col1 col2   col3
# 0   NaN  abc  111.0
# 1   2.0  def  222.0
# 5   6.0  def  555.0
# 4   5.0  pqr  111.0
# 3   4.0  xyz  444.0
# 2   3.0  NaN    NaN

# %%
df1.isnull()
# Out:
#     col1   col2   col3
# 0   True  False  False
# 1  False  False  False
# 2  False   True   True
# 3  False  False  False
# 4  False  False  False
# 5  False  False  False

# %%
df1.dropna()
# Out:
#    col1 col2   col3
# 1   2.0  def  222.0
# 3   4.0  xyz  444.0
# 4   5.0  pqr  111.0
# 5   6.0  def  555.0
